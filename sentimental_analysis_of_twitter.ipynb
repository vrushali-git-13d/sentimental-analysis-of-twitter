# %%
import re 
import tweepy 
from tweepy import OAuthHandler 
from textblob import TextBlob 
  
class TwitterClient(object): 
    ''' 
    Generic Twitter Class for sentiment analysis. 
    '''
    def __init__(self): 
        ''' 
        Class constructor or initialization method. 
        '''
        # keys and tokens from the Twitter Dev Console 
        consumer_key = 'xxxxxxxxxxxx'
        consumer_secret = 'xxxxxxxxxxxxxxxxxxxxxxxx'
        access_token = 'xxxxxxxx-xxxxxxxxxxx'
        access_token_secret = 'xxxxxxxxxxxxxxxxxxxx'
  
        # attempt authentication 
        try: 
            # create OAuthHandler object 
            self.auth = OAuthHandler(consumer_key, consumer_secret) 
            # set access token and secret 
            self.auth.set_access_token(access_token, access_token_secret) 
            # create tweepy API object to fetch tweets 
            self.api = tweepy.API(self.auth) 
        except: 
            print("Error: Authentication Failed") 
  
    def clean_tweet(self, tweet): 
        ''' 
        Utility function to clean tweet text by removing links, special characters 
        using simple regex statements. 
        '''
        return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split()) 
  
    def get_tweet_sentiment(self, tweet): 
        ''' 
        Utility function to classify sentiment of passed tweet 
        using textblob's sentiment method 
        '''
        # create TextBlob object of passed tweet text 
        analysis = TextBlob(self.clean_tweet(tweet)) 
        # set sentiment 
        if analysis.sentiment.polarity > 0: 
            return 'positive'
        elif analysis.sentiment.polarity == 0: 
            return 'neutral'
        else: 
            return 'negative'
  
    def get_tweets(self, query, count = 10): 
        ''' 
        Main function to fetch tweets and parse them. 
        '''
        # empty list to store parsed tweets 
        tweets = [] 
  
        try: 
            # call twitter api to fetch tweets 
            fetched_tweets = self.api.search(q = query, count = count) 
  
            # parsing tweets one by one 
            for tweet in fetched_tweets: 
                # empty dictionary to store required params of a tweet 
                parsed_tweet = {} 
  
                # saving text of tweet 
                parsed_tweet['text'] = tweet.text 
                # saving sentiment of tweet 
                parsed_tweet['sentiment'] = self.get_tweet_sentiment(tweet.text) 
  
                # appending parsed tweet to tweets list 
                if tweet.retweet_count > 0: 
                    # if tweet has retweets, ensure that it is appended only once 
                    if parsed_tweet not in tweets: 
                        tweets.append(parsed_tweet) 
                else: 
                    tweets.append(parsed_tweet) 
  
            # return parsed tweets 
            return tweets 
  
        except tweepy.TweepError as e: 
            # print error (if any) 
            print("Error : " + str(e)) 
  
def main(): 
    # creating object of TwitterClient Class 
    api = TwitterClient() 
    # calling function to get tweets 
    tweets = api.get_tweets(query = 'Elon Musk', count = 200) 
  
    # picking positive tweets from tweets 
    ptweets = [tweet for tweet in tweets if tweet['sentiment'] == 'positive'] 
    # percentage of positive tweets 
    print("Positive tweets percentage: {} %".format(100*len(ptweets)/len(tweets))) 
    # picking negative tweets from tweets 
    ntweets = [tweet for tweet in tweets if tweet['sentiment'] == 'negative'] 
    # percentage of negative tweets 
    print("Negative tweets percentage: {} %".format(100*len(ntweets)/len(tweets))) 
    # percentage of neutral tweets 
    print("Neutral tweets percentage: {} %".format(100*(len(tweets) -(len( ntweets )+len( ptweets)))/len(tweets))) 
  
    # printing first 5 positive tweets 
    print("\n\nPositive tweets:") 
    for tweet in ptweets[:10]: 
        print(tweet['text']) 
  
    # printing first 5 negative tweets 
    print("\n\nNegative tweets:") 
    for tweet in ntweets[:10]: 
        print(tweet['text']) 
  
if __name__ == "__main__": 
    # calling main function 
    main()
# Out:
# Positive tweets percentage: 26.666666666666668 %
# Negative tweets percentage: 18.333333333333332 %
# Neutral tweets percentage: 55.0 %
#
#
# Positive tweets:
# RT @BernieSanders: While 92 million can't afford health care, the 4 richest Americans are now worth $512.8 billion:
#
# - Jeff Bezos: $193 bil…
# Who wants Elon Musk(@elonmusk) should be president of America. If he will be president America is gonna be chill https://t.co/e5S82BBlUz
# Going to qrt so people know why
#
# Mostly by association, he has worked with many transphobic figures including ben s… https://t.co/SY9LNTWEAf
# Why Elon Musk is Different From Normal People?
# #ElonMusk  #Facts
#
# https://t.co/OhY2U1mYIm https://t.co/uD85f04BDR
# RT @ICannot_Enough: @BernieSanders Environmentalism has many enemies, but Elon Musk isn’t among them. https://t.co/pOwyQEcH7s
# @KillSection Fr
# Yooo
# Happy birthday my guy
#
# Heres a photo but related to this topic what so ever https://t.co/3xvvBavHq5
# I look at Elon Musk different than from the investment vehicle he offers, which is investing in his company Tesla… https://t.co/PX9Ivckvpq
# @TheROCFiles He just an Elon Musk with a black belt. Nothing super about him 🤷🏽‍♂️
# @patrick_oshag Elon Musk's twitter account is worth about $400B right now.
# @leafvsflower Or else Elon Musk is piping his own lofi into his brain 😲
#
#
# Negative tweets:
# @Elon_Musk_com Thank you , pic so random lmaoo
# I hate those posts about “success” or “motivation” and include a questionable quote by Dwayne Johnson or Elon Musk.… https://t.co/vaiA8JzCQA
# @KillSection I fucking hate Twitter like gimme a edit tweet button ffs
# RT @theemilyaccount: warren buffett contributes less to society than elon musk
# RT @zshahan3: Elon Musk is certainly not perfect &amp; has various flaws, but I can’t think of another person who has both thought &amp; done so mu…
# @Raqzfnr @fynn2ndd @ymxritz nein bro handys sind so fucking alt, arm wer noch nicht die gehirnchipprototypen von elon musk hat
# @AZ_Bassit Be serious ironman is fictitious, modelled after Elon Musk
# Checkmate flat-Eathers! Congrats to Elon Musk for making history #checkmate #eathers #congrats #making #history https://t.co/zKDzaRrTfY
# How do you like Elon Musk? 😆
#
# @LenidexGraphics
# @ZlazeCreative
# @ZenhyCreatesXII
# @OgonekDzn
# @SnexzyCreations
#
# sorry… https://t.co/Ehf2cVdvzw
# @LazyGinger Also, for a half second, I read Elon, as in Musk.
